# %%
### importing all the required libraries 
from sklearn.datasets import load_files       
from keras.utils import np_utils
import numpy as np
from sklearn.model_selection import train_test_split
from keras.preprocessing import image ,image                 
from tqdm import tqdm
from keras.applications.mobilenetv2 import MobileNetV2, preprocess_input
from keras.applications.nasnet import NASNetMobile
from keras.applications.resnet50 import ResNet50, preprocess_input
from keras.callbacks import ModelCheckpoint  
import cv2
from keras.layers import Conv2D,Conv3D, MaxPooling2D, GlobalAveragePooling2D,GlobalAveragePooling3D
from keras.layers import Dropout, Flatten, Dense
from keras.models import Sequential
from keras.layers.normalization import BatchNormalization
import win32com.client
from random import randint
import time
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

speaker = win32com.client.Dispatch("SAPI.SpVoice")
# Out:
# Using TensorFlow backend.

# %%
### loading all the dataset and give each subfolder a number to present each class
data_training = load_files("./data/training/")
x_train = np.array(data_training['filenames'])
y_train = np_utils.to_categorical(np.array(data_training['target']), 9)

data_validation = load_files("./data/validation/")
x_valid = np.array(data_validation['filenames'])
y_valid = np_utils.to_categorical(np.array(data_validation['target']), 9)

data_testing = load_files("./data/testing/")
x_test = np.array(data_testing['filenames'])
y_test = np_utils.to_categorical(np.array(data_testing['target']), 9)

# %%
### RANDOM MODEL CLASSIFIER 

counter=0
for true_value in data_testing['target']:
    if(true_value==randint(0,9)):
        counter=counter+1
        
accuracy=(counter/data_testing['target'].shape[0])   
print("The accuracy of a random model={}%".format(accuracy*100))
# Out:
# The accuracy of a random model=9.192200557103064%

# %%
def path_to_tensor(img_path):
    # loads RGB image as PIL.Image.Image type
    img = image.load_img(img_path, target_size=(224, 224))
    # convert PIL.Image.Image type to 3D tensor with shape (224, 224, 3)
    x = image.img_to_array(img)
    # convert 3D tensor to 4D tensor with shape (1, 224, 224, 3) and return 4D tensor
    return np.expand_dims(x, axis=0)

def paths_to_tensor(img_paths):
    list_of_tensors = [path_to_tensor(img_path) for img_path in tqdm(img_paths)]
    return np.vstack(list_of_tensors)

train_tensor=paths_to_tensor(x_train)
valid_tensor=paths_to_tensor(x_valid)
test_tensor=paths_to_tensor(x_test)
# Out:
# 100%|██████████| 1520/1520 [00:19<00:00, 79.24it/s]
# 100%|██████████| 243/243 [00:01<00:00, 130.04it/s]
# 100%|██████████| 359/359 [00:05<00:00, 71.28it/s]

# %%
valid_resnet=ResNet50(weights='imagenet', include_top=False).predict(preprocess_input(valid_tensor))
print("done")

test_resnet=ResNet50(weights='imagenet', include_top=False).predict(preprocess_input(test_tensor))
print("done")

train_resnet=ResNet50(weights='imagenet', include_top=False).predict(preprocess_input(train_tensor))
print ("done")


np.save("train_resnet", train_resnet)
np.save("valid_resnet", valid_resnet)
np.save("test_resnet", test_resnet)
# Out:
# done
# done
# done

# %%
valid_resnet=np.load('valid_resnet.npy')
test_resnet=np.load('test_resnet.npy')
train_resnet=np.load('train_resnet.npy')

# %%
Resnet50_model = Sequential()
Resnet50_model.add(GlobalAveragePooling2D(input_shape=(None,None,2048)))
Resnet50_model.add(Dense(9, activation='softmax'))

Resnet50_model.summary()
Resnet50_model.compile(optimizer='adagrad', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# global_average_pooling2d_9 ( (None, 2048)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 9)                 18441
# =================================================================
# Total params: 18,441
# Trainable params: 18,441
# Non-trainable params: 0
# _________________________________________________________________

# %%
### TODO: Train the model.

checkpointer = ModelCheckpoint(filepath='weights.best.Resnet50.hdf5', 
                               verbose=1, save_best_only=True)

history=Resnet50_model.fit(train_resnet, y_train, 
          validation_data=(valid_resnet, y_valid),
          epochs=50, batch_size=20, callbacks=[checkpointer], verbose=2)
# Out:
# Train on 1520 samples, validate on 243 samples
# Epoch 1/50
#  - 1s - loss: 0.9517 - acc: 0.7250 - val_loss: 0.3502 - val_acc: 0.8807
#
# Epoch 00001: val_loss improved from inf to 0.35019, saving model to weights.best.Resnet50.hdf5
# Epoch 2/50
#  - 1s - loss: 0.3476 - acc: 0.8914 - val_loss: 0.2746 - val_acc: 0.9053
#
# Epoch 00002: val_loss improved from 0.35019 to 0.27458, saving model to weights.best.Resnet50.hdf5
# Epoch 3/50
#  - 1s - loss: 0.2574 - acc: 0.9217 - val_loss: 0.1980 - val_acc: 0.9424
#
# Epoch 00003: val_loss improved from 0.27458 to 0.19804, saving model to weights.best.Resnet50.hdf5
# Epoch 4/50
#  - 1s - loss: 0.2136 - acc: 0.9382 - val_loss: 0.1463 - val_acc: 0.9835
#
# Epoch 00004: val_loss improved from 0.19804 to 0.14628, saving model to weights.best.Resnet50.hdf5
# Epoch 5/50
#  - 1s - loss: 0.1780 - acc: 0.9533 - val_loss: 0.1258 - val_acc: 0.9835
#
# Epoch 00005: val_loss improved from 0.14628 to 0.12579, saving model to weights.best.Resnet50.hdf5
# Epoch 6/50
#  - 1s - loss: 0.1576 - acc: 0.9658 - val_loss: 0.1122 - val_acc: 0.9959
#
# Epoch 00006: val_loss improved from 0.12579 to 0.11224, saving model to weights.best.Resnet50.hdf5
# Epoch 7/50
#  - 1s - loss: 0.1385 - acc: 0.9730 - val_loss: 0.1003 - val_acc: 1.0000
#
# Epoch 00007: val_loss improved from 0.11224 to 0.10035, saving model to weights.best.Resnet50.hdf5
# Epoch 8/50
#  - 1s - loss: 0.1265 - acc: 0.9776 - val_loss: 0.0982 - val_acc: 0.9877
#
# Epoch 00008: val_loss improved from 0.10035 to 0.09822, saving model to weights.best.Resnet50.hdf5
# Epoch 9/50
#  - 1s - loss: 0.1148 - acc: 0.9809 - val_loss: 0.0815 - val_acc: 1.0000
#
# Epoch 00009: val_loss improved from 0.09822 to 0.08153, saving model to weights.best.Resnet50.hdf5
# Epoch 10/50
#  - 1s - loss: 0.1056 - acc: 0.9855 - val_loss: 0.0847 - val_acc: 0.9959
#
# Epoch 00010: val_loss did not improve from 0.08153
# Epoch 11/50
#  - 1s - loss: 0.0976 - acc: 0.9868 - val_loss: 0.0743 - val_acc: 1.0000
#
# Epoch 00011: val_loss improved from 0.08153 to 0.07427, saving model to weights.best.Resnet50.hdf5
# Epoch 12/50
#  - 1s - loss: 0.0919 - acc: 0.9901 - val_loss: 0.0695 - val_acc: 0.9959
#
# Epoch 00012: val_loss improved from 0.07427 to 0.06955, saving model to weights.best.Resnet50.hdf5
# Epoch 13/50
#  - 1s - loss: 0.0855 - acc: 0.9921 - val_loss: 0.0665 - val_acc: 1.0000
#
# Epoch 00013: val_loss improved from 0.06955 to 0.06651, saving model to weights.best.Resnet50.hdf5
# Epoch 14/50
#  - 1s - loss: 0.0799 - acc: 0.9934 - val_loss: 0.0607 - val_acc: 1.0000
#
# Epoch 00014: val_loss improved from 0.06651 to 0.06067, saving model to weights.best.Resnet50.hdf5
# Epoch 15/50
#  - 1s - loss: 0.0764 - acc: 0.9947 - val_loss: 0.0590 - val_acc: 1.0000
#
# Epoch 00015: val_loss improved from 0.06067 to 0.05904, saving model to weights.best.Resnet50.hdf5
# Epoch 16/50
#  - 1s - loss: 0.0719 - acc: 0.9961 - val_loss: 0.0557 - val_acc: 1.0000
#
# Epoch 00016: val_loss improved from 0.05904 to 0.05566, saving model to weights.best.Resnet50.hdf5
# Epoch 17/50
#  - 1s - loss: 0.0685 - acc: 0.9954 - val_loss: 0.0533 - val_acc: 0.9959
#
# Epoch 00017: val_loss improved from 0.05566 to 0.05334, saving model to weights.best.Resnet50.hdf5
# Epoch 18/50
#  - 1s - loss: 0.0654 - acc: 0.9961 - val_loss: 0.0512 - val_acc: 1.0000
#
# Epoch 00018: val_loss improved from 0.05334 to 0.05122, saving model to weights.best.Resnet50.hdf5
# Epoch 19/50
#  - 1s - loss: 0.0624 - acc: 0.9967 - val_loss: 0.0504 - val_acc: 1.0000
#
# Epoch 00019: val_loss improved from 0.05122 to 0.05042, saving model to weights.best.Resnet50.hdf5
# Epoch 20/50
#  - 1s - loss: 0.0598 - acc: 0.9961 - val_loss: 0.0461 - val_acc: 1.0000
#
# Epoch 00020: val_loss improved from 0.05042 to 0.04606, saving model to weights.best.Resnet50.hdf5
# Epoch 21/50
#  - 1s - loss: 0.0574 - acc: 0.9967 - val_loss: 0.0453 - val_acc: 1.0000
#
# Epoch 00021: val_loss improved from 0.04606 to 0.04532, saving model to weights.best.Resnet50.hdf5
# Epoch 22/50
#  - 1s - loss: 0.0547 - acc: 0.9967 - val_loss: 0.0449 - val_acc: 1.0000
#
# Epoch 00022: val_loss improved from 0.04532 to 0.04486, saving model to weights.best.Resnet50.hdf5
# Epoch 23/50
#  - 1s - loss: 0.0527 - acc: 0.9967 - val_loss: 0.0408 - val_acc: 1.0000
#
# Epoch 00023: val_loss improved from 0.04486 to 0.04076, saving model to weights.best.Resnet50.hdf5
# Epoch 24/50
#  - 1s - loss: 0.0514 - acc: 0.9961 - val_loss: 0.0420 - val_acc: 1.0000
#
# Epoch 00024: val_loss did not improve from 0.04076
# Epoch 25/50
#  - 1s - loss: 0.0490 - acc: 0.9967 - val_loss: 0.0413 - val_acc: 1.0000
#
# Epoch 00025: val_loss did not improve from 0.04076
# Epoch 26/50
#  - 1s - loss: 0.0477 - acc: 0.9961 - val_loss: 0.0394 - val_acc: 1.0000
#
# Epoch 00026: val_loss improved from 0.04076 to 0.03941, saving model to weights.best.Resnet50.hdf5
# Epoch 27/50
#  - 1s - loss: 0.0460 - acc: 0.9967 - val_loss: 0.0372 - val_acc: 1.0000
#
# Epoch 00027: val_loss improved from 0.03941 to 0.03720, saving model to weights.best.Resnet50.hdf5
# Epoch 28/50
#  - 1s - loss: 0.0449 - acc: 0.9974 - val_loss: 0.0371 - val_acc: 1.0000
#
# Epoch 00028: val_loss improved from 0.03720 to 0.03713, saving model to weights.best.Resnet50.hdf5
# Epoch 29/50
#  - 1s - loss: 0.0434 - acc: 0.9974 - val_loss: 0.0353 - val_acc: 1.0000
#
# Epoch 00029: val_loss improved from 0.03713 to 0.03525, saving model to weights.best.Resnet50.hdf5
# Epoch 30/50
#  - 1s - loss: 0.0422 - acc: 0.9967 - val_loss: 0.0346 - val_acc: 1.0000
#
# Epoch 00030: val_loss improved from 0.03525 to 0.03463, saving model to weights.best.Resnet50.hdf5
# Epoch 31/50
#  - 1s - loss: 0.0410 - acc: 0.9974 - val_loss: 0.0330 - val_acc: 1.0000
#
# Epoch 00031: val_loss improved from 0.03463 to 0.03296, saving model to weights.best.Resnet50.hdf5
# Epoch 32/50
#  - 1s - loss: 0.0400 - acc: 0.9967 - val_loss: 0.0322 - val_acc: 1.0000
#
# Epoch 00032: val_loss improved from 0.03296 to 0.03219, saving model to weights.best.Resnet50.hdf5
# Epoch 33/50
#  - 1s - loss: 0.0390 - acc: 0.9967 - val_loss: 0.0315 - val_acc: 1.0000
#
# Epoch 00033: val_loss improved from 0.03219 to 0.03151, saving model to weights.best.Resnet50.hdf5
# Epoch 34/50
#  - 1s - loss: 0.0379 - acc: 0.9954 - val_loss: 0.0314 - val_acc: 1.0000
#
# Epoch 00034: val_loss improved from 0.03151 to 0.03143, saving model to weights.best.Resnet50.hdf5
# Epoch 35/50
#  - 1s - loss: 0.0368 - acc: 0.9967 - val_loss: 0.0308 - val_acc: 1.0000
#
# Epoch 00035: val_loss improved from 0.03143 to 0.03075, saving model to weights.best.Resnet50.hdf5
# Epoch 36/50
#  - 1s - loss: 0.0360 - acc: 0.9974 - val_loss: 0.0303 - val_acc: 1.0000
#
# Epoch 00036: val_loss improved from 0.03075 to 0.03025, saving model to weights.best.Resnet50.hdf5
# Epoch 37/50
#  - 1s - loss: 0.0355 - acc: 0.9974 - val_loss: 0.0288 - val_acc: 1.0000
#
# Epoch 00037: val_loss improved from 0.03025 to 0.02877, saving model to weights.best.Resnet50.hdf5
# Epoch 38/50
#  - 1s - loss: 0.0343 - acc: 0.9974 - val_loss: 0.0281 - val_acc: 1.0000
#
# Epoch 00038: val_loss improved from 0.02877 to 0.02814, saving model to weights.best.Resnet50.hdf5
# Epoch 39/50
#  - 1s - loss: 0.0336 - acc: 0.9967 - val_loss: 0.0288 - val_acc: 1.0000
#
# Epoch 00039: val_loss did not improve from 0.02814
# Epoch 40/50
#  - 1s - loss: 0.0330 - acc: 0.9967 - val_loss: 0.0274 - val_acc: 1.0000
#
# Epoch 00040: val_loss improved from 0.02814 to 0.02743, saving model to weights.best.Resnet50.hdf5
# Epoch 41/50
#  - 1s - loss: 0.0323 - acc: 0.9967 - val_loss: 0.0264 - val_acc: 1.0000
#
# Epoch 00041: val_loss improved from 0.02743 to 0.02643, saving model to weights.best.Resnet50.hdf5
# Epoch 42/50
#  - 1s - loss: 0.0316 - acc: 0.9974 - val_loss: 0.0260 - val_acc: 1.0000
#
# Epoch 00042: val_loss improved from 0.02643 to 0.02602, saving model to weights.best.Resnet50.hdf5
# Epoch 43/50
#  - 1s - loss: 0.0309 - acc: 0.9974 - val_loss: 0.0254 - val_acc: 1.0000
#
# Epoch 00043: val_loss improved from 0.02602 to 0.02538, saving model to weights.best.Resnet50.hdf5
# Epoch 44/50
#  - 1s - loss: 0.0302 - acc: 0.9974 - val_loss: 0.0254 - val_acc: 1.0000
#
# Epoch 00044: val_loss improved from 0.02538 to 0.02537, saving model to weights.best.Resnet50.hdf5
# Epoch 45/50
#  - 1s - loss: 0.0298 - acc: 0.9967 - val_loss: 0.0252 - val_acc: 1.0000
#
# Epoch 00045: val_loss improved from 0.02537 to 0.02521, saving model to weights.best.Resnet50.hdf5
# Epoch 46/50
#  - 1s - loss: 0.0294 - acc: 0.9967 - val_loss: 0.0241 - val_acc: 1.0000
# Epoch 00046: val_loss improved from 0.02521 to 0.02412, saving model to weights.best.Resnet50.hdf5
# Epoch 47/50
#  - 1s - loss: 0.0287 - acc: 0.9967 - val_loss: 0.0241 - val_acc: 1.0000
#
# Epoch 00047: val_loss did not improve from 0.02412
# Epoch 48/50
#  - 1s - loss: 0.0282 - acc: 0.9967 - val_loss: 0.0240 - val_acc: 1.0000
#
# Epoch 00048: val_loss improved from 0.02412 to 0.02399, saving model to weights.best.Resnet50.hdf5
# Epoch 49/50
#  - 1s - loss: 0.0278 - acc: 0.9974 - val_loss: 0.0227 - val_acc: 1.0000
#
# Epoch 00049: val_loss improved from 0.02399 to 0.02267, saving model to weights.best.Resnet50.hdf5
# Epoch 50/50
#  - 1s - loss: 0.0273 - acc: 0.9967 - val_loss: 0.0231 - val_acc: 1.0000
#
# Epoch 00050: val_loss did not improve from 0.02267

# %%
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Valid'], loc='upper left')
plt.savefig('resnet50_accuracy.png')

plt.show()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Valid'], loc='upper left')
plt.savefig('resnet50_loss.png')

plt.show()

# %%
Resnet50_model.load_weights('weights.best.Resnet50.hdf5')
Resnet50_predictions = [np.argmax(Resnet50_model.predict(np.expand_dims(feature, axis=0))) for feature in test_resnet]

# report test accuracy
test_accuracy = 100*np.sum(np.array(Resnet50_predictions)==np.argmax(y_test, axis=1))/len(Resnet50_predictions)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 85.5153%

# %%
classes_name=['bathroom','bedroom','closet','corridor','dining_room','kitchen','livingroom','pantry','stairscase']

# %%
def voice_assist(num):
    
    
        if (num==0):
            speaker.Speak("It's a bathroom!")

        elif (num==1):
            speaker.Speak("It's a bedroom!")  
        elif (num==2):
            speaker.Speak("It's a children room ! ")  
        elif (num==3):
            speaker.Speak("It's a closet!")  
        elif (num==4):
            speaker.Speak("It's a corridor!")  
        elif (num==5):
            speaker.Speak("It's a dining room!")  
        elif (num==6):
            speaker.Speak("It's a kitchen!")  
        elif (num==7):
            speaker.Speak("It's a living room!")  
        elif (num==8):
            speaker.Speak("It's a pantry!")  
        elif (num==9):
            speaker.Speak("It's a staircase!")

# %%
    prev_class_num=20
    accuracy=0.6
    cap = cv2.VideoCapture(0)
    font = cv2.FONT_HERSHEY_SIMPLEX


    while 1:
        start=time.time()
        ret, img = cap.read()
        frame=cv2.resize(img, (224, 224))
        frame = image.img_to_array(frame)
        frame=np.expand_dims(frame,axis=0)
        prediction=Resnet50_model.predict(ResNet50(weights='imagenet', include_top=False).predict(preprocess_input(frame)))

        class_num=np.argmax(prediction)
        if(prediction[0][class_num]>accuracy):
            cv2.putText(img,classes_name[class_num],(10,224), font, 1, (255, 255, 255), 2, cv2.LINE_AA)
            if( (class_num != prev_class_num)):

                prev_class_num=class_num
                voice_assist(class_num)
        cv2.imshow('img',img)
        end=time.time()
        
        k = cv2.waitKey(30) & 0xff
        if k == 27:
            break
    cap.release()
    cv2.destroyAllWindows()

    print("The time taken to process one frame is ={}".format(end-start))
# Out:
# The time taken to process one frame is =16.583635807037354

# %%
model=MobileNetV2(weights='imagenet', include_top=False)
# Out:
# C:\Users\blackice\Anaconda3\envs\test\lib\site-packages\keras_applications\mobilenet_v2.py:315: UserWarning: MobileNet shape is undefined. Weights for input shape(224, 224) will be loaded.
#   warnings.warn('MobileNet shape is undefined.'

# %%
valid_mobile=model.predict(preprocess_input(valid_tensor))
print("done")

test_mobile=model.predict(preprocess_input(test_tensor))
print("done")

train_mobile=model.predict(preprocess_input(train_tensor))
print ("done")


np.save("train_mobile", train_mobile)
np.save("valid_mobile", valid_mobile)
np.save("test_mobile", test_mobile)
# Out:
# done
# done
# done

# %%
valid_mobile=np.load('valid_mobile.npy')
test_mobile=np.load('test_mobile.npy')
train_mobile=np.load('train_mobile.npy')

# %%
my_model = Sequential()

my_model.add(GlobalAveragePooling2D(input_shape=(7,7,1280)))
my_model.add(Dense(9, activation='softmax'))


my_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# global_average_pooling2d_10  (None, 1280)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 9)                 11529
# =================================================================
# Total params: 11,529
# Trainable params: 11,529
# Non-trainable params: 0
# _________________________________________________________________

# %%
my_model.compile(optimizer='adagrad', loss='categorical_crossentropy', metrics=['accuracy'])
checkpointer = ModelCheckpoint(filepath='weights.best.mobile_model.hdf5', 
                               verbose=1, save_best_only=True)

history1=my_model.fit(train_mobile, y_train, 
          validation_data=(valid_mobile, y_valid),
          epochs=200, batch_size=100, callbacks=[checkpointer], verbose=2)
# Out:
# Train on 1520 samples, validate on 243 samples
# Epoch 1/200
#  - 3s - loss: 0.1487 - acc: 0.9638 - val_loss: 0.1813 - val_acc: 0.9753
#
# Epoch 00001: val_loss improved from inf to 0.18131, saving model to weights.best.mobile_model.hdf5
# Epoch 2/200
#  - 0s - loss: 0.0539 - acc: 0.9974 - val_loss: 0.1686 - val_acc: 0.9794
#
# Epoch 00002: val_loss improved from 0.18131 to 0.16858, saving model to weights.best.mobile_model.hdf5
# Epoch 3/200
#  - 1s - loss: 0.0522 - acc: 0.9980 - val_loss: 0.1796 - val_acc: 0.9753
#
# Epoch 00003: val_loss did not improve from 0.16858
# Epoch 4/200
#  - 1s - loss: 0.0522 - acc: 0.9967 - val_loss: 0.1840 - val_acc: 0.9794
#
# Epoch 00004: val_loss did not improve from 0.16858
# Epoch 5/200
#  - 1s - loss: 0.0506 - acc: 0.9974 - val_loss: 0.2025 - val_acc: 0.9671
#
# Epoch 00005: val_loss did not improve from 0.16858
# Epoch 6/200
#  - 1s - loss: 0.0492 - acc: 0.9974 - val_loss: 0.1837 - val_acc: 0.9753
#
# Epoch 00006: val_loss did not improve from 0.16858
# Epoch 7/200
#  - 0s - loss: 0.0494 - acc: 0.9974 - val_loss: 0.1760 - val_acc: 0.9794
#
# Epoch 00007: val_loss did not improve from 0.16858
# Epoch 8/200
#  - 0s - loss: 0.0488 - acc: 0.9967 - val_loss: 0.1698 - val_acc: 0.9794
#
# Epoch 00008: val_loss did not improve from 0.16858
# Epoch 9/200
#  - 1s - loss: 0.0487 - acc: 0.9974 - val_loss: 0.1719 - val_acc: 0.9794
#
# Epoch 00009: val_loss did not improve from 0.16858
# Epoch 10/200
#  - 1s - loss: 0.0481 - acc: 0.9967 - val_loss: 0.1627 - val_acc: 0.9794
#
# Epoch 00010: val_loss improved from 0.16858 to 0.16272, saving model to weights.best.mobile_model.hdf5
# Epoch 11/200
#  - 1s - loss: 0.0477 - acc: 0.9974 - val_loss: 0.1787 - val_acc: 0.9794
#
# Epoch 00011: val_loss did not improve from 0.16272
# Epoch 12/200
#  - 1s - loss: 0.0486 - acc: 0.9974 - val_loss: 0.1672 - val_acc: 0.9794
#
# Epoch 00012: val_loss did not improve from 0.16272
# Epoch 13/200
#  - 1s - loss: 0.0466 - acc: 0.9980 - val_loss: 0.1795 - val_acc: 0.9753
#
# Epoch 00013: val_loss did not improve from 0.16272
# Epoch 14/200
#  - 1s - loss: 0.0460 - acc: 0.9980 - val_loss: 0.1788 - val_acc: 0.9753
#
# Epoch 00014: val_loss did not improve from 0.16272
# Epoch 15/200
#  - 1s - loss: 0.0463 - acc: 0.9974 - val_loss: 0.1819 - val_acc: 0.9753
#
# Epoch 00015: val_loss did not improve from 0.16272
# Epoch 16/200
#  - 1s - loss: 0.0457 - acc: 0.9974 - val_loss: 0.1834 - val_acc: 0.9753
#
# Epoch 00016: val_loss did not improve from 0.16272
# Epoch 17/200
#  - 1s - loss: 0.0450 - acc: 0.9974 - val_loss: 0.1694 - val_acc: 0.9794
#
# Epoch 00017: val_loss did not improve from 0.16272
# Epoch 18/200
#  - 1s - loss: 0.0447 - acc: 0.9980 - val_loss: 0.1757 - val_acc: 0.9753
#
# Epoch 00018: val_loss did not improve from 0.16272
# Epoch 19/200
#  - 1s - loss: 0.0448 - acc: 0.9974 - val_loss: 0.1837 - val_acc: 0.9753
#
# Epoch 00019: val_loss did not improve from 0.16272
# Epoch 20/200
#  - 1s - loss: 0.0444 - acc: 0.9974 - val_loss: 0.1753 - val_acc: 0.9753
#
# Epoch 00020: val_loss did not improve from 0.16272
# Epoch 21/200
#  - 1s - loss: 0.0449 - acc: 0.9974 - val_loss: 0.1794 - val_acc: 0.9753
#
# Epoch 00021: val_loss did not improve from 0.16272
# Epoch 22/200
#  - 1s - loss: 0.0440 - acc: 0.9974 - val_loss: 0.1750 - val_acc: 0.9753
#
# Epoch 00022: val_loss did not improve from 0.16272
# Epoch 23/200
#  - 0s - loss: 0.0436 - acc: 0.9974 - val_loss: 0.1735 - val_acc: 0.9794
#
# Epoch 00023: val_loss did not improve from 0.16272
# Epoch 24/200
#  - 0s - loss: 0.0441 - acc: 0.9974 - val_loss: 0.1694 - val_acc: 0.9794
#
# Epoch 00024: val_loss did not improve from 0.16272
# Epoch 25/200
#  - 0s - loss: 0.0434 - acc: 0.9980 - val_loss: 0.1787 - val_acc: 0.9753
#
# Epoch 00025: val_loss did not improve from 0.16272
# Epoch 26/200
#  - 0s - loss: 0.0434 - acc: 0.9967 - val_loss: 0.1817 - val_acc: 0.9753
#
# Epoch 00026: val_loss did not improve from 0.16272
# Epoch 27/200
#  - 1s - loss: 0.0434 - acc: 0.9967 - val_loss: 0.1727 - val_acc: 0.9794
#
# Epoch 00027: val_loss did not improve from 0.16272
# Epoch 28/200
#  - 0s - loss: 0.0426 - acc: 0.9974 - val_loss: 0.1886 - val_acc: 0.9753
#
# Epoch 00028: val_loss did not improve from 0.16272
# Epoch 29/200
#  - 0s - loss: 0.0430 - acc: 0.9974 - val_loss: 0.1869 - val_acc: 0.9753
#
# Epoch 00029: val_loss did not improve from 0.16272
# Epoch 30/200
#  - 1s - loss: 0.0434 - acc: 0.9974 - val_loss: 0.1802 - val_acc: 0.9794
#
# Epoch 00030: val_loss did not improve from 0.16272
# Epoch 31/200
#  - 1s - loss: 0.0421 - acc: 0.9974 - val_loss: 0.1731 - val_acc: 0.9794
#
# Epoch 00031: val_loss did not improve from 0.16272
# Epoch 32/200
#  - 1s - loss: 0.0418 - acc: 0.9980 - val_loss: 0.1767 - val_acc: 0.9794
#
# Epoch 00032: val_loss did not improve from 0.16272
# Epoch 33/200
#  - 1s - loss: 0.0426 - acc: 0.9980 - val_loss: 0.1730 - val_acc: 0.9794
#
# Epoch 00033: val_loss did not improve from 0.16272
# Epoch 34/200
#  - 1s - loss: 0.0414 - acc: 0.9974 - val_loss: 0.1854 - val_acc: 0.9753
#
# Epoch 00034: val_loss did not improve from 0.16272
# Epoch 35/200
#  - 0s - loss: 0.0412 - acc: 0.9980 - val_loss: 0.1636 - val_acc: 0.9794
#
# Epoch 00035: val_loss did not improve from 0.16272
# Epoch 36/200
#  - 0s - loss: 0.0410 - acc: 0.9980 - val_loss: 0.1812 - val_acc: 0.9753
#
# Epoch 00036: val_loss did not improve from 0.16272
# Epoch 37/200
#  - 1s - loss: 0.0409 - acc: 0.9980 - val_loss: 0.1736 - val_acc: 0.9753
#
# Epoch 00037: val_loss did not improve from 0.16272
# Epoch 38/200
#  - 0s - loss: 0.0406 - acc: 0.9974 - val_loss: 0.1849 - val_acc: 0.9753
#
# Epoch 00038: val_loss did not improve from 0.16272
# Epoch 39/200
#  - 0s - loss: 0.0403 - acc: 0.9974 - val_loss: 0.1688 - val_acc: 0.9794
#
# Epoch 00039: val_loss did not improve from 0.16272
# Epoch 40/200
#  - 1s - loss: 0.0402 - acc: 0.9980 - val_loss: 0.1763 - val_acc: 0.9753
#
# Epoch 00040: val_loss did not improve from 0.16272
# Epoch 41/200
#  - 1s - loss: 0.0400 - acc: 0.9980 - val_loss: 0.1877 - val_acc: 0.9753
#
# Epoch 00041: val_loss did not improve from 0.16272
# Epoch 42/200
#  - 1s - loss: 0.0402 - acc: 0.9974 - val_loss: 0.1755 - val_acc: 0.9794
#
# Epoch 00042: val_loss did not improve from 0.16272
# Epoch 43/200
#  - 1s - loss: 0.0397 - acc: 0.9974 - val_loss: 0.1747 - val_acc: 0.9753
#
# Epoch 00043: val_loss did not improve from 0.16272
# Epoch 44/200
#  - 1s - loss: 0.0399 - acc: 0.9974 - val_loss: 0.1731 - val_acc: 0.9794
#
# Epoch 00044: val_loss did not improve from 0.16272
# Epoch 45/200
#  - 1s - loss: 0.0393 - acc: 0.9974 - val_loss: 0.1704 - val_acc: 0.9794
#
# Epoch 00045: val_loss did not improve from 0.16272
# Epoch 46/200
#  - 0s - loss: 0.0390 - acc: 0.9980 - val_loss: 0.1693 - val_acc: 0.9794
#
# Epoch 00046: val_loss did not improve from 0.16272
# Epoch 47/200
#  - 1s - loss: 0.0391 - acc: 0.9974 - val_loss: 0.1838 - val_acc: 0.9753
#
# Epoch 00047: val_loss did not improve from 0.16272
# Epoch 48/200
#  - 0s - loss: 0.0389 - acc: 0.9967 - val_loss: 0.1817 - val_acc: 0.9753
#
# Epoch 00048: val_loss did not improve from 0.16272
# Epoch 49/200
#  - 1s - loss: 0.0387 - acc: 0.9967 - val_loss: 0.1761 - val_acc: 0.9753
#
# Epoch 00049: val_loss did not improve from 0.16272
# Epoch 50/200
#  - 0s - loss: 0.0389 - acc: 0.9967 - val_loss: 0.1721 - val_acc: 0.9794
#
# Epoch 00050: val_loss did not improve from 0.16272
# Epoch 51/200
#  - 1s - loss: 0.0384 - acc: 0.9967 - val_loss: 0.1711 - val_acc: 0.9794
#
# Epoch 00051: val_loss did not improve from 0.16272
# Epoch 52/200
#  - 0s - loss: 0.0384 - acc: 0.9967 - val_loss: 0.1731 - val_acc: 0.9753
#
# Epoch 00052: val_loss did not improve from 0.16272
# Epoch 53/200
#  - 0s - loss: 0.0382 - acc: 0.9974 - val_loss: 0.1837 - val_acc: 0.9753
#
# Epoch 00053: val_loss did not improve from 0.16272
# Epoch 54/200
#  - 1s - loss: 0.0377 - acc: 0.9974 - val_loss: 0.1789 - val_acc: 0.9753
#
# Epoch 00054: val_loss did not improve from 0.16272
# Epoch 55/200
#  - 0s - loss: 0.0381 - acc: 0.9974 - val_loss: 0.1770 - val_acc: 0.9794
#
# Epoch 00055: val_loss did not improve from 0.16272
# Epoch 56/200
#  - 1s - loss: 0.0377 - acc: 0.9974 - val_loss: 0.1662 - val_acc: 0.9794
#
# Epoch 00056: val_loss did not improve from 0.16272
# Epoch 57/200
#  - 1s - loss: 0.0375 - acc: 0.9974 - val_loss: 0.1893 - val_acc: 0.9794
#
# Epoch 00057: val_loss did not improve from 0.16272
# Epoch 58/200
#  - 0s - loss: 0.0391 - acc: 0.9974 - val_loss: 0.1814 - val_acc: 0.9753
#
# Epoch 00058: val_loss did not improve from 0.16272
# Epoch 59/200
#  - 1s - loss: 0.0376 - acc: 0.9980 - val_loss: 0.1710 - val_acc: 0.9794
# Epoch 00059: val_loss did not improve from 0.16272
# Epoch 60/200
#  - 0s - loss: 0.0372 - acc: 0.9974 - val_loss: 0.1698 - val_acc: 0.9794
#
# Epoch 00060: val_loss did not improve from 0.16272
# Epoch 61/200
#  - 0s - loss: 0.0373 - acc: 0.9974 - val_loss: 0.1708 - val_acc: 0.9794
#
# Epoch 00061: val_loss did not improve from 0.16272
# Epoch 62/200
#  - 0s - loss: 0.0370 - acc: 0.9974 - val_loss: 0.1767 - val_acc: 0.9794
#
# Epoch 00062: val_loss did not improve from 0.16272
# Epoch 63/200
#  - 1s - loss: 0.0367 - acc: 0.9974 - val_loss: 0.1782 - val_acc: 0.9794
#
# Epoch 00063: val_loss did not improve from 0.16272
# Epoch 64/200
#  - 0s - loss: 0.0368 - acc: 0.9961 - val_loss: 0.1792 - val_acc: 0.9794
#
# Epoch 00064: val_loss did not improve from 0.16272
# Epoch 65/200
#  - 0s - loss: 0.0364 - acc: 0.9987 - val_loss: 0.1670 - val_acc: 0.9794
#
# Epoch 00065: val_loss did not improve from 0.16272
# Epoch 66/200
#  - 1s - loss: 0.0364 - acc: 0.9974 - val_loss: 0.1704 - val_acc: 0.9794
#
# Epoch 00066: val_loss did not improve from 0.16272
# Epoch 67/200
#  - 0s - loss: 0.0365 - acc: 0.9974 - val_loss: 0.1678 - val_acc: 0.9794
#
# Epoch 00067: val_loss did not improve from 0.16272
# Epoch 68/200
#  - 0s - loss: 0.0360 - acc: 0.9974 - val_loss: 0.1787 - val_acc: 0.9753
#
# Epoch 00068: val_loss did not improve from 0.16272
# Epoch 69/200
#  - 0s - loss: 0.0360 - acc: 0.9974 - val_loss: 0.1742 - val_acc: 0.9794
#
# Epoch 00069: val_loss did not improve from 0.16272
# Epoch 70/200
#  - 0s - loss: 0.0359 - acc: 0.9974 - val_loss: 0.1778 - val_acc: 0.9753
#
# Epoch 00070: val_loss did not improve from 0.16272
# Epoch 71/200
#  - 1s - loss: 0.0359 - acc: 0.9961 - val_loss: 0.1714 - val_acc: 0.9794
#
# Epoch 00071: val_loss did not improve from 0.16272
# Epoch 72/200
#  - 1s - loss: 0.0357 - acc: 0.9967 - val_loss: 0.1706 - val_acc: 0.9794
#
# Epoch 00072: val_loss did not improve from 0.16272
# Epoch 73/200
#  - 1s - loss: 0.0354 - acc: 0.9974 - val_loss: 0.1837 - val_acc: 0.9753
#
# Epoch 00073: val_loss did not improve from 0.16272
# Epoch 74/200
#  - 0s - loss: 0.0354 - acc: 0.9974 - val_loss: 0.1767 - val_acc: 0.9794
#
# Epoch 00074: val_loss did not improve from 0.16272
# Epoch 75/200
#  - 1s - loss: 0.0353 - acc: 0.9967 - val_loss: 0.1727 - val_acc: 0.9794
#
# Epoch 00075: val_loss did not improve from 0.16272
# Epoch 76/200
#  - 0s - loss: 0.0351 - acc: 0.9974 - val_loss: 0.1672 - val_acc: 0.9794
#
# Epoch 00076: val_loss did not improve from 0.16272
# Epoch 77/200
#  - 1s - loss: 0.0350 - acc: 0.9974 - val_loss: 0.1720 - val_acc: 0.9794
#
# Epoch 00077: val_loss did not improve from 0.16272
# Epoch 78/200
#  - 0s - loss: 0.0349 - acc: 0.9974 - val_loss: 0.1702 - val_acc: 0.9794
#
# Epoch 00078: val_loss did not improve from 0.16272
# Epoch 79/200
#  - 0s - loss: 0.0347 - acc: 0.9974 - val_loss: 0.1730 - val_acc: 0.9794
#
# Epoch 00079: val_loss did not improve from 0.16272
# Epoch 80/200
#  - 0s - loss: 0.0348 - acc: 0.9967 - val_loss: 0.1757 - val_acc: 0.9794
#
# Epoch 00080: val_loss did not improve from 0.16272
# Epoch 81/200
#  - 0s - loss: 0.0346 - acc: 0.9974 - val_loss: 0.1786 - val_acc: 0.9794
#
# Epoch 00081: val_loss did not improve from 0.16272
# Epoch 82/200
#  - 0s - loss: 0.0354 - acc: 0.9967 - val_loss: 0.1756 - val_acc: 0.9794
#
# Epoch 00082: val_loss did not improve from 0.16272
# Epoch 83/200
#  - 0s - loss: 0.0345 - acc: 0.9974 - val_loss: 0.1739 - val_acc: 0.9794
#
# Epoch 00083: val_loss did not improve from 0.16272
# Epoch 84/200
#  - 1s - loss: 0.0345 - acc: 0.9974 - val_loss: 0.1832 - val_acc: 0.9753
#
# Epoch 00084: val_loss did not improve from 0.16272
# Epoch 85/200
#  - 1s - loss: 0.0344 - acc: 0.9967 - val_loss: 0.1754 - val_acc: 0.9753
#
# Epoch 00085: val_loss did not improve from 0.16272
# Epoch 86/200
#  - 0s - loss: 0.0342 - acc: 0.9967 - val_loss: 0.1745 - val_acc: 0.9753
#
# Epoch 00086: val_loss did not improve from 0.16272
# Epoch 87/200
#  - 0s - loss: 0.0339 - acc: 0.9980 - val_loss: 0.1714 - val_acc: 0.9794
#
# Epoch 00087: val_loss did not improve from 0.16272
# Epoch 88/200
#  - 0s - loss: 0.0340 - acc: 0.9974 - val_loss: 0.1689 - val_acc: 0.9794
#
# Epoch 00088: val_loss did not improve from 0.16272
# Epoch 89/200
#  - 0s - loss: 0.0338 - acc: 0.9974 - val_loss: 0.1730 - val_acc: 0.9794
#
# Epoch 00089: val_loss did not improve from 0.16272
# Epoch 90/200
#  - 0s - loss: 0.0337 - acc: 0.9980 - val_loss: 0.1739 - val_acc: 0.9794
#
# Epoch 00090: val_loss did not improve from 0.16272
# Epoch 91/200
#  - 1s - loss: 0.0336 - acc: 0.9974 - val_loss: 0.1667 - val_acc: 0.9794
#
# Epoch 00091: val_loss did not improve from 0.16272
# Epoch 92/200
#  - 0s - loss: 0.0335 - acc: 0.9980 - val_loss: 0.1822 - val_acc: 0.9753
#
# Epoch 00092: val_loss did not improve from 0.16272
# Epoch 93/200
#  - 0s - loss: 0.0334 - acc: 0.9974 - val_loss: 0.1734 - val_acc: 0.9794
#
# Epoch 00093: val_loss did not improve from 0.16272
# Epoch 94/200
#  - 0s - loss: 0.0335 - acc: 0.9967 - val_loss: 0.1799 - val_acc: 0.9753
#
# Epoch 00094: val_loss did not improve from 0.16272
# Epoch 95/200
#  - 0s - loss: 0.0330 - acc: 0.9974 - val_loss: 0.1715 - val_acc: 0.9794
#
# Epoch 00095: val_loss did not improve from 0.16272
# Epoch 96/200
#  - 0s - loss: 0.0333 - acc: 0.9967 - val_loss: 0.1782 - val_acc: 0.9794
#
# Epoch 00096: val_loss did not improve from 0.16272
# Epoch 97/200
#  - 0s - loss: 0.0331 - acc: 0.9974 - val_loss: 0.1795 - val_acc: 0.9794
#
# Epoch 00097: val_loss did not improve from 0.16272
# Epoch 98/200
#  - 0s - loss: 0.0332 - acc: 0.9961 - val_loss: 0.1772 - val_acc: 0.9753
#
# Epoch 00098: val_loss did not improve from 0.16272
# Epoch 99/200
#  - 1s - loss: 0.0329 - acc: 0.9974 - val_loss: 0.1748 - val_acc: 0.9794
#
# Epoch 00099: val_loss did not improve from 0.16272
# Epoch 100/200
#  - 0s - loss: 0.0328 - acc: 0.9961 - val_loss: 0.1817 - val_acc: 0.9753
#
# Epoch 00100: val_loss did not improve from 0.16272
# Epoch 101/200
#  - 1s - loss: 0.0327 - acc: 0.9974 - val_loss: 0.1736 - val_acc: 0.9794
#
# Epoch 00101: val_loss did not improve from 0.16272
# Epoch 102/200
#  - 0s - loss: 0.0327 - acc: 0.9974 - val_loss: 0.1748 - val_acc: 0.9794
#
# Epoch 00102: val_loss did not improve from 0.16272
# Epoch 103/200
#  - 1s - loss: 0.0326 - acc: 0.9967 - val_loss: 0.1784 - val_acc: 0.9794
#
# Epoch 00103: val_loss did not improve from 0.16272
# Epoch 104/200
#  - 1s - loss: 0.0326 - acc: 0.9974 - val_loss: 0.1679 - val_acc: 0.9794
#
# Epoch 00104: val_loss did not improve from 0.16272
# Epoch 105/200
#  - 1s - loss: 0.0325 - acc: 0.9974 - val_loss: 0.1731 - val_acc: 0.9794
#
# Epoch 00105: val_loss did not improve from 0.16272
# Epoch 106/200
#  - 1s - loss: 0.0326 - acc: 0.9980 - val_loss: 0.1729 - val_acc: 0.9794
#
# Epoch 00106: val_loss did not improve from 0.16272
# Epoch 107/200
#  - 0s - loss: 0.0324 - acc: 0.9974 - val_loss: 0.1749 - val_acc: 0.9794
#
# Epoch 00107: val_loss did not improve from 0.16272
# Epoch 108/200
#  - 1s - loss: 0.0322 - acc: 0.9980 - val_loss: 0.1692 - val_acc: 0.9794
#
# Epoch 00108: val_loss did not improve from 0.16272
# Epoch 109/200
#  - 1s - loss: 0.0321 - acc: 0.9974 - val_loss: 0.1755 - val_acc: 0.9794
#
# Epoch 00109: val_loss did not improve from 0.16272
# Epoch 110/200
#  - 0s - loss: 0.0319 - acc: 0.9974 - val_loss: 0.1752 - val_acc: 0.9794
#
# Epoch 00110: val_loss did not improve from 0.16272
# Epoch 111/200
#  - 1s - loss: 0.0319 - acc: 0.9974 - val_loss: 0.1755 - val_acc: 0.9794
#
# Epoch 00111: val_loss did not improve from 0.16272
# Epoch 112/200
#  - 0s - loss: 0.0317 - acc: 0.9980 - val_loss: 0.1729 - val_acc: 0.9794
#
# Epoch 00112: val_loss did not improve from 0.16272
# Epoch 113/200
#  - 1s - loss: 0.0317 - acc: 0.9974 - val_loss: 0.1765 - val_acc: 0.9794
#
# Epoch 00113: val_loss did not improve from 0.16272
# Epoch 114/200
#  - 1s - loss: 0.0315 - acc: 0.9974 - val_loss: 0.1743 - val_acc: 0.9794
#
# Epoch 00114: val_loss did not improve from 0.16272
# Epoch 115/200
#  - 1s - loss: 0.0316 - acc: 0.9974 - val_loss: 0.1705 - val_acc: 0.9794
#
# Epoch 00115: val_loss did not improve from 0.16272
# Epoch 116/200
#  - 0s - loss: 0.0316 - acc: 0.9967 - val_loss: 0.1726 - val_acc: 0.9794
#
# Epoch 00116: val_loss did not improve from 0.16272
# Epoch 117/200
#  - 0s - loss: 0.0313 - acc: 0.9974 - val_loss: 0.1694 - val_acc: 0.9794
#
# Epoch 00117: val_loss did not improve from 0.16272
# Epoch 118/200
#  - 0s - loss: 0.0313 - acc: 0.9967 - val_loss: 0.1765 - val_acc: 0.9794
#
# Epoch 00118: val_loss did not improve from 0.16272
# Epoch 119/200
#  - 0s - loss: 0.0312 - acc: 0.9974 - val_loss: 0.1765 - val_acc: 0.9794
# Epoch 00119: val_loss did not improve from 0.16272
# Epoch 120/200
#  - 0s - loss: 0.0311 - acc: 0.9967 - val_loss: 0.1660 - val_acc: 0.9794
#
# Epoch 00120: val_loss did not improve from 0.16272
# Epoch 121/200
#  - 1s - loss: 0.0312 - acc: 0.9961 - val_loss: 0.1764 - val_acc: 0.9753
#
# Epoch 00121: val_loss did not improve from 0.16272
# Epoch 122/200
#  - 1s - loss: 0.0310 - acc: 0.9967 - val_loss: 0.1714 - val_acc: 0.9794
#
# Epoch 00122: val_loss did not improve from 0.16272
# Epoch 123/200
#  - 0s - loss: 0.0308 - acc: 0.9980 - val_loss: 0.1788 - val_acc: 0.9753
#
# Epoch 00123: val_loss did not improve from 0.16272
# Epoch 124/200
#  - 1s - loss: 0.0309 - acc: 0.9961 - val_loss: 0.1751 - val_acc: 0.9794
#
# Epoch 00124: val_loss did not improve from 0.16272
# Epoch 125/200
#  - 0s - loss: 0.0309 - acc: 0.9974 - val_loss: 0.1729 - val_acc: 0.9794
#
# Epoch 00125: val_loss did not improve from 0.16272
# Epoch 126/200
#  - 0s - loss: 0.0306 - acc: 0.9974 - val_loss: 0.1761 - val_acc: 0.9794
#
# Epoch 00126: val_loss did not improve from 0.16272
# Epoch 127/200
#  - 1s - loss: 0.0306 - acc: 0.9974 - val_loss: 0.1738 - val_acc: 0.9794
#
# Epoch 00127: val_loss did not improve from 0.16272
# Epoch 128/200
#  - 0s - loss: 0.0304 - acc: 0.9980 - val_loss: 0.1751 - val_acc: 0.9794
#
# Epoch 00128: val_loss did not improve from 0.16272
# Epoch 129/200
#  - 1s - loss: 0.0305 - acc: 0.9974 - val_loss: 0.1769 - val_acc: 0.9794
#
# Epoch 00129: val_loss did not improve from 0.16272
# Epoch 130/200
#  - 0s - loss: 0.0303 - acc: 0.9974 - val_loss: 0.1768 - val_acc: 0.9753
#
# Epoch 00130: val_loss did not improve from 0.16272
# Epoch 131/200
#  - 1s - loss: 0.0303 - acc: 0.9974 - val_loss: 0.1761 - val_acc: 0.9794
#
# Epoch 00131: val_loss did not improve from 0.16272
# Epoch 132/200
#  - 0s - loss: 0.0303 - acc: 0.9967 - val_loss: 0.1788 - val_acc: 0.9753
#
# Epoch 00132: val_loss did not improve from 0.16272
# Epoch 133/200
#  - 0s - loss: 0.0302 - acc: 0.9974 - val_loss: 0.1740 - val_acc: 0.9794
#
# Epoch 00133: val_loss did not improve from 0.16272
# Epoch 134/200
#  - 1s - loss: 0.0302 - acc: 0.9974 - val_loss: 0.1768 - val_acc: 0.9753
#
# Epoch 00134: val_loss did not improve from 0.16272
# Epoch 135/200
#  - 1s - loss: 0.0300 - acc: 0.9980 - val_loss: 0.1756 - val_acc: 0.9794
#
# Epoch 00135: val_loss did not improve from 0.16272
# Epoch 136/200
#  - 1s - loss: 0.0299 - acc: 0.9967 - val_loss: 0.1724 - val_acc: 0.9794
#
# Epoch 00136: val_loss did not improve from 0.16272
# Epoch 137/200
#  - 0s - loss: 0.0300 - acc: 0.9967 - val_loss: 0.1727 - val_acc: 0.9794
#
# Epoch 00137: val_loss did not improve from 0.16272
# Epoch 138/200
#  - 0s - loss: 0.0297 - acc: 0.9980 - val_loss: 0.1760 - val_acc: 0.9794
#
# Epoch 00138: val_loss did not improve from 0.16272
# Epoch 139/200
#  - 0s - loss: 0.0298 - acc: 0.9974 - val_loss: 0.1818 - val_acc: 0.9794
#
# Epoch 00139: val_loss did not improve from 0.16272
# Epoch 140/200
#  - 0s - loss: 0.0302 - acc: 0.9980 - val_loss: 0.1775 - val_acc: 0.9753
#
# Epoch 00140: val_loss did not improve from 0.16272
# Epoch 141/200
#  - 0s - loss: 0.0298 - acc: 0.9980 - val_loss: 0.1769 - val_acc: 0.9753
#
# Epoch 00141: val_loss did not improve from 0.16272
# Epoch 142/200
#  - 1s - loss: 0.0297 - acc: 0.9974 - val_loss: 0.1748 - val_acc: 0.9794
#
# Epoch 00142: val_loss did not improve from 0.16272
# Epoch 143/200
#  - 0s - loss: 0.0296 - acc: 0.9967 - val_loss: 0.1703 - val_acc: 0.9794
#
# Epoch 00143: val_loss did not improve from 0.16272
# Epoch 144/200
#  - 0s - loss: 0.0293 - acc: 0.9980 - val_loss: 0.1761 - val_acc: 0.9753
#
# Epoch 00144: val_loss did not improve from 0.16272
# Epoch 145/200
#  - 0s - loss: 0.0295 - acc: 0.9967 - val_loss: 0.1743 - val_acc: 0.9794
#
# Epoch 00145: val_loss did not improve from 0.16272
# Epoch 146/200
#  - 0s - loss: 0.0294 - acc: 0.9967 - val_loss: 0.1754 - val_acc: 0.9794
#
# Epoch 00146: val_loss did not improve from 0.16272
# Epoch 147/200
#  - 0s - loss: 0.0294 - acc: 0.9961 - val_loss: 0.1792 - val_acc: 0.9794
#
# Epoch 00147: val_loss did not improve from 0.16272
# Epoch 148/200
#  - 1s - loss: 0.0293 - acc: 0.9967 - val_loss: 0.1711 - val_acc: 0.9794
#
# Epoch 00148: val_loss did not improve from 0.16272
# Epoch 149/200
#  - 1s - loss: 0.0291 - acc: 0.9974 - val_loss: 0.1738 - val_acc: 0.9794
#
# Epoch 00149: val_loss did not improve from 0.16272
# Epoch 150/200
#  - 0s - loss: 0.0291 - acc: 0.9961 - val_loss: 0.1747 - val_acc: 0.9794
#
# Epoch 00150: val_loss did not improve from 0.16272
# Epoch 151/200
#  - 0s - loss: 0.0289 - acc: 0.9974 - val_loss: 0.1759 - val_acc: 0.9794
#
# Epoch 00151: val_loss did not improve from 0.16272
# Epoch 152/200
#  - 0s - loss: 0.0290 - acc: 0.9974 - val_loss: 0.1760 - val_acc: 0.9794
#
# Epoch 00152: val_loss did not improve from 0.16272
# Epoch 153/200
#  - 1s - loss: 0.0289 - acc: 0.9967 - val_loss: 0.1773 - val_acc: 0.9794
#
# Epoch 00153: val_loss did not improve from 0.16272
# Epoch 154/200
#  - 1s - loss: 0.0290 - acc: 0.9974 - val_loss: 0.1763 - val_acc: 0.9753
#
# Epoch 00154: val_loss did not improve from 0.16272
# Epoch 155/200
#  - 1s - loss: 0.0289 - acc: 0.9974 - val_loss: 0.1686 - val_acc: 0.9794
#
# Epoch 00155: val_loss did not improve from 0.16272
# Epoch 156/200
#  - 1s - loss: 0.0287 - acc: 0.9980 - val_loss: 0.1742 - val_acc: 0.9794
#
# Epoch 00156: val_loss did not improve from 0.16272
# Epoch 157/200
#  - 0s - loss: 0.0288 - acc: 0.9980 - val_loss: 0.1733 - val_acc: 0.9794
#
# Epoch 00157: val_loss did not improve from 0.16272
# Epoch 158/200
#  - 0s - loss: 0.0286 - acc: 0.9980 - val_loss: 0.1742 - val_acc: 0.9794
#
# Epoch 00158: val_loss did not improve from 0.16272
# Epoch 159/200
#  - 1s - loss: 0.0285 - acc: 0.9974 - val_loss: 0.1732 - val_acc: 0.9794
#
# Epoch 00159: val_loss did not improve from 0.16272
# Epoch 160/200
#  - 0s - loss: 0.0285 - acc: 0.9980 - val_loss: 0.1736 - val_acc: 0.9794
#
# Epoch 00160: val_loss did not improve from 0.16272
# Epoch 161/200
#  - 1s - loss: 0.0284 - acc: 0.9974 - val_loss: 0.1756 - val_acc: 0.9753
#
# Epoch 00161: val_loss did not improve from 0.16272
# Epoch 162/200
#  - 1s - loss: 0.0284 - acc: 0.9967 - val_loss: 0.1737 - val_acc: 0.9794
#
# Epoch 00162: val_loss did not improve from 0.16272
# Epoch 163/200
#  - 0s - loss: 0.0283 - acc: 0.9974 - val_loss: 0.1749 - val_acc: 0.9753
#
# Epoch 00163: val_loss did not improve from 0.16272
# Epoch 164/200
#  - 0s - loss: 0.0283 - acc: 0.9967 - val_loss: 0.1748 - val_acc: 0.9794
#
# Epoch 00164: val_loss did not improve from 0.16272
# Epoch 165/200
#  - 0s - loss: 0.0281 - acc: 0.9974 - val_loss: 0.1713 - val_acc: 0.9794
#
# Epoch 00165: val_loss did not improve from 0.16272
# Epoch 166/200
#  - 1s - loss: 0.0280 - acc: 0.9974 - val_loss: 0.1745 - val_acc: 0.9794
#
# Epoch 00166: val_loss did not improve from 0.16272
# Epoch 167/200
#  - 1s - loss: 0.0281 - acc: 0.9980 - val_loss: 0.1677 - val_acc: 0.9794
#
# Epoch 00167: val_loss did not improve from 0.16272
# Epoch 168/200
#  - 1s - loss: 0.0280 - acc: 0.9967 - val_loss: 0.1751 - val_acc: 0.9794
#
# Epoch 00168: val_loss did not improve from 0.16272
# Epoch 169/200
#  - 1s - loss: 0.0280 - acc: 0.9967 - val_loss: 0.1750 - val_acc: 0.9794
#
# Epoch 00169: val_loss did not improve from 0.16272
# Epoch 170/200
#  - 0s - loss: 0.0278 - acc: 0.9974 - val_loss: 0.1753 - val_acc: 0.9794
#
# Epoch 00170: val_loss did not improve from 0.16272
# Epoch 171/200
#  - 0s - loss: 0.0278 - acc: 0.9974 - val_loss: 0.1769 - val_acc: 0.9794
#
# Epoch 00171: val_loss did not improve from 0.16272
# Epoch 172/200
#  - 0s - loss: 0.0279 - acc: 0.9967 - val_loss: 0.1750 - val_acc: 0.9794
#
# Epoch 00172: val_loss did not improve from 0.16272
# Epoch 173/200
#  - 1s - loss: 0.0280 - acc: 0.9980 - val_loss: 0.1705 - val_acc: 0.9794
#
# Epoch 00173: val_loss did not improve from 0.16272
# Epoch 174/200
#  - 1s - loss: 0.0277 - acc: 0.9980 - val_loss: 0.1712 - val_acc: 0.9794
#
# Epoch 00174: val_loss did not improve from 0.16272
# Epoch 175/200
#  - 0s - loss: 0.0276 - acc: 0.9967 - val_loss: 0.1737 - val_acc: 0.9794
#
# Epoch 00175: val_loss did not improve from 0.16272
# Epoch 176/200
#  - 1s - loss: 0.0276 - acc: 0.9974 - val_loss: 0.1723 - val_acc: 0.9794
#
# Epoch 00176: val_loss did not improve from 0.16272
# Epoch 177/200
#  - 0s - loss: 0.0275 - acc: 0.9980 - val_loss: 0.1759 - val_acc: 0.9753
#
# Epoch 00177: val_loss did not improve from 0.16272
# Epoch 178/200
#  - 0s - loss: 0.0275 - acc: 0.9980 - val_loss: 0.1698 - val_acc: 0.9794
# Epoch 00178: val_loss did not improve from 0.16272
# Epoch 179/200
#  - 0s - loss: 0.0274 - acc: 0.9967 - val_loss: 0.1727 - val_acc: 0.9794
#
# Epoch 00179: val_loss did not improve from 0.16272
# Epoch 180/200
#  - 1s - loss: 0.0273 - acc: 0.9980 - val_loss: 0.1664 - val_acc: 0.9794
#
# Epoch 00180: val_loss did not improve from 0.16272
# Epoch 181/200
#  - 0s - loss: 0.0273 - acc: 0.9974 - val_loss: 0.1750 - val_acc: 0.9794
#
# Epoch 00181: val_loss did not improve from 0.16272
# Epoch 182/200
#  - 0s - loss: 0.0272 - acc: 0.9974 - val_loss: 0.1736 - val_acc: 0.9794
#
# Epoch 00182: val_loss did not improve from 0.16272
# Epoch 183/200
#  - 0s - loss: 0.0272 - acc: 0.9980 - val_loss: 0.1753 - val_acc: 0.9794
#
# Epoch 00183: val_loss did not improve from 0.16272
# Epoch 184/200
#  - 1s - loss: 0.0272 - acc: 0.9961 - val_loss: 0.1717 - val_acc: 0.9794
#
# Epoch 00184: val_loss did not improve from 0.16272
# Epoch 185/200
#  - 0s - loss: 0.0271 - acc: 0.9974 - val_loss: 0.1738 - val_acc: 0.9794
#
# Epoch 00185: val_loss did not improve from 0.16272
# Epoch 186/200
#  - 1s - loss: 0.0271 - acc: 0.9967 - val_loss: 0.1768 - val_acc: 0.9794
#
# Epoch 00186: val_loss did not improve from 0.16272
# Epoch 187/200
#  - 0s - loss: 0.0270 - acc: 0.9980 - val_loss: 0.1724 - val_acc: 0.9794
#
# Epoch 00187: val_loss did not improve from 0.16272
# Epoch 188/200
#  - 1s - loss: 0.0268 - acc: 0.9980 - val_loss: 0.1740 - val_acc: 0.9794
#
# Epoch 00188: val_loss did not improve from 0.16272
# Epoch 189/200
#  - 0s - loss: 0.0267 - acc: 0.9974 - val_loss: 0.1758 - val_acc: 0.9794
#
# Epoch 00189: val_loss did not improve from 0.16272
# Epoch 190/200
#  - 1s - loss: 0.0269 - acc: 0.9974 - val_loss: 0.1747 - val_acc: 0.9794
#
# Epoch 00190: val_loss did not improve from 0.16272
# Epoch 191/200
#  - 0s - loss: 0.0269 - acc: 0.9967 - val_loss: 0.1769 - val_acc: 0.9753
#
# Epoch 00191: val_loss did not improve from 0.16272
# Epoch 192/200
#  - 0s - loss: 0.0268 - acc: 0.9980 - val_loss: 0.1717 - val_acc: 0.9794
#
# Epoch 00192: val_loss did not improve from 0.16272
# Epoch 193/200
#  - 0s - loss: 0.0267 - acc: 0.9974 - val_loss: 0.1755 - val_acc: 0.9794
#
# Epoch 00193: val_loss did not improve from 0.16272
# Epoch 194/200
#  - 0s - loss: 0.0266 - acc: 0.9967 - val_loss: 0.1739 - val_acc: 0.9794
#
# Epoch 00194: val_loss did not improve from 0.16272
# Epoch 195/200
#  - 0s - loss: 0.0266 - acc: 0.9974 - val_loss: 0.1731 - val_acc: 0.9794
#
# Epoch 00195: val_loss did not improve from 0.16272
# Epoch 196/200
#  - 1s - loss: 0.0266 - acc: 0.9974 - val_loss: 0.1740 - val_acc: 0.9794
#
# Epoch 00196: val_loss did not improve from 0.16272
# Epoch 197/200
#  - 0s - loss: 0.0265 - acc: 0.9980 - val_loss: 0.1740 - val_acc: 0.9794
#
# Epoch 00197: val_loss did not improve from 0.16272
# Epoch 198/200
#  - 1s - loss: 0.0265 - acc: 0.9974 - val_loss: 0.1733 - val_acc: 0.9794
#
# Epoch 00198: val_loss did not improve from 0.16272
# Epoch 199/200
#  - 1s - loss: 0.0263 - acc: 0.9974 - val_loss: 0.1727 - val_acc: 0.9794
#
# Epoch 00199: val_loss did not improve from 0.16272
# Epoch 200/200
#  - 1s - loss: 0.0263 - acc: 0.9974 - val_loss: 0.1744 - val_acc: 0.9794
#
# Epoch 00200: val_loss did not improve from 0.16272

# %%
plt.plot(history1.history['acc'])
plt.plot(history1.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Valid'], loc='upper left')
plt.savefig('mobilenet_accuracy.png')

plt.show()
plt.plot(history1.history['loss'])
plt.plot(history1.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Valid'], loc='upper left')
plt.savefig('mobilenet_loss.png')

plt.show()

# %%
my_model.load_weights('weights.best.mobile_model.hdf5')

my_model_predictions = [np.argmax(my_model.predict(np.expand_dims(feature, axis=0))) for feature in test_mobile]

# report test accuracy
test_accuracy = 100*np.sum(np.array(my_model_predictions)==np.argmax(y_test, axis=1))/len(my_model_predictions)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 55.9889%

# %%
prev_class_num=20
accuracy=0.8
cap = cv2.VideoCapture(0)
font = cv2.FONT_HERSHEY_SIMPLEX

while 1:
    start=time.time()
    ret, img = cap.read()
    frame=cv2.resize(img, (224, 224))
    frame = image.img_to_array(frame)
    frame=np.expand_dims(frame,axis=0)
    prediction=my_model.predict(model.predict(preprocess_input(frame)))
    class_num=np.argmax(prediction)
    if(prediction[0][class_num]>accuracy):
        cv2.putText(img,classes_name[class_num],(10,224), font, 1, (255, 255, 255), 2, cv2.LINE_AA)
        if( (class_num != prev_class_num)):

            prev_class_num=class_num
            voice_assist(class_num)
    cv2.imshow('img',img)
    end=time.time()
    k = cv2.waitKey(30) & 0xff
    if k == 27:
        break
cap.release()
cv2.destroyAllWindows()
print("The time taken to process one frame is ={}".format(end-start))
# Out:
# The time taken to process one frame is =0.1994647979736328

# %%
datagen = ImageDataGenerator(rotation_range=20)

subdirectory=classes_name[8]

train_generator =datagen.flow_from_directory(
    directory="./data/augmented/",
    classes=[subdirectory],
    color_mode="rgb",
    save_format='jpg',
    batch_size=20,
    class_mode="categorical",
    save_to_dir="./data/augmented//"+subdirectory,
    save_prefix="augmented",
    follow_links=True,
)
datagen.fit(train_generator)

# %%
### loading all the dataset and give each subfolder a number to present each class
data_training_aug = load_files("./data/augmented//")
x_train_aug = np.array(data_training_aug['filenames'])
y_train_aug = np_utils.to_categorical(np.array(data_training_aug['target']), 9)

train_tensor_aug=paths_to_tensor(x_train_aug)

# %%
train_mobile_aug=model.predict(preprocess_input(train_tensor_aug))
print ("done")


np.save("train_mobile_aug", train_mobile_aug)
# Out:
# done

# %%
train_mobile_aug=np.load('train_mobile_aug.npy')

# %%
my_model_augement = Sequential()
my_model_augement.add(GlobalAveragePooling2D())
my_model_augement
my_model_augement.add(Dense(9, activation='softmax'))
my_model_augement.summary()

# %%
my_model_augement.compile(optimizer='adagrad', loss='categorical_crossentropy', metrics=['accuracy'])
checkpointer = ModelCheckpoint(filepath='weights.best.mobile_model_augement.hdf5', 
                               verbose=1, save_best_only=True)

history1=my_model_augement.fit(train_mobile_aug, y_train_aug, 
          validation_data=(valid_mobile, y_valid),
          epochs=50, batch_size=50, callbacks=[checkpointer], verbose=2)

# %%
plt.plot(history1.history['acc'])
plt.plot(history1.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Valid'], loc='upper left')
plt.show()
plt.plot(history1.history['loss'])
plt.plot(history1.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Valid'], loc='upper left')
plt.show()

# %%
my_model_augement.load_weights('weights.best.mobile_model_augement.hdf5')

my_model_predictions1 = [np.argmax(my_model_augement.predict(np.expand_dims(feature, axis=0))) for feature in test_mobile]

# report test accuracy
test_accuracy = 100*np.sum(np.array(my_model_predictions1)==np.argmax(y_test, axis=1))/len(my_model_predictions1)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 42.6184%

# %%
prev_class_num=20
accuracy=0.8
cap = cv2.VideoCapture(0)
font = cv2.FONT_HERSHEY_SIMPLEX

while 1:
    start=time.time()
    ret, img = cap.read()
    frame=cv2.resize(img, (224, 224))
    frame = image.img_to_array(frame)
    frame=np.expand_dims(frame,axis=0)
    prediction=my_model.predict(model.predict(preprocess_input(frame)))
    class_num=np.argmax(prediction)
    if(prediction[0][class_num]>accuracy):
        cv2.putText(img,classes_name[class_num],(10,224), font, 1, (255, 255, 255), 2, cv2.LINE_AA)
        if( (class_num != prev_class_num)):

            prev_class_num=class_num
            voice_assist(class_num)
    cv2.imshow('img',img)
    end=time.time()
    k = cv2.waitKey(30) & 0xff
    if k == 27:
        break
cap.release()
cv2.destroyAllWindows()
print("The time taken to process one frame is ={}".format(end-start))
# Out:
# The time taken to process one frame is =0.2323765754699707
